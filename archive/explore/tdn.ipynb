# %%
import os
import cv2
import numpy as np
from matplotlib import pyplot as plt

img_dir = 'data/ants/frames_cropped_224'
img_dir = 'data/userTrain_images_resized_224'

# %%
videos = os.listdir(img_dir)
img_folder = os.path.join(img_dir, '0da1203b7713025b7711')
img_list = os.listdir(img_folder)
img_list = sorted(img_list)
img_list = [img for img in img_list if not 'full' in img]
for i in range(1, 30):
    # print(f"{i}.jpg")
    # img_i = cv2.imread(os.path.join(img_folder, f"{i}.jpg"), cv2.IMREAD_GRAYSCALE)
    # img_j = cv2.imread(os.path.join(img_folder, f"{i+1}.jpg"), cv2.IMREAD_GRAYSCALE)
    print("%08d.jpg" % i)
    print("%08d.jpg" % (i + 1))
    img_i = cv2.imread(os.path.join(img_folder, "%08d.jpg" % i), cv2.IMREAD_GRAYSCALE)
    img_j = cv2.imread(os.path.join(img_folder, "%08d.jpg" % (i + 1)), cv2.IMREAD_GRAYSCALE)
    img = img_j - img_i
    diff_id = np.where(img != 0)
    # for i in range(len(diff_id[0])):
    #     print(img[diff_id[0][i], diff_id[1][i]])
    # print(diff)
    plt.imshow(img)
    plt.show()
# Out:
# 00000001.jpg
# 00000002.jpg
# 00000002.jpg
# 00000003.jpg
# 00000003.jpg
# 00000004.jpg
# 00000004.jpg
# 00000005.jpg
# 00000005.jpg
# 00000006.jpg
# 00000006.jpg
# 00000007.jpg
# 00000007.jpg
# 00000008.jpg
# 00000008.jpg
# 00000009.jpg
# 00000009.jpg
# 00000010.jpg
# 00000010.jpg
# 00000011.jpg
# 00000011.jpg
# 00000012.jpg
# 00000012.jpg
# 00000013.jpg
# 00000013.jpg
# 00000014.jpg
# 00000014.jpg
# 00000015.jpg
# 00000015.jpg
# 00000016.jpg
# 00000016.jpg
# 00000017.jpg
# 00000017.jpg
# 00000018.jpg
# 00000018.jpg
# 00000019.jpg
# 00000019.jpg
# 00000020.jpg
# 00000020.jpg
# 00000021.jpg
# 00000021.jpg
# 00000022.jpg
# 00000022.jpg
# 00000023.jpg
# 00000023.jpg
# 00000024.jpg
# 00000024.jpg
# 00000025.jpg
# 00000025.jpg
# 00000026.jpg
# 00000026.jpg
# 00000027.jpg
# 00000027.jpg
# 00000028.jpg
# 00000028.jpg
# 00000029.jpg
# 00000029.jpg
# 00000030.jpg

# %%
videos = os.listdir(img_dir)
img_folder = os.path.join(img_dir, '0da1203b7713025b7711')
img_list = os.listdir(img_folder)
img_list = sorted(img_list)
img_list = [img for img in img_list if 'full' in img]
for i in range(1, 30):
    # print(f"{i}.jpg")
    # img_i = cv2.imread(os.path.join(img_folder, f"{i}.jpg"), cv2.IMREAD_GRAYSCALE)
    # img_j = cv2.imread(os.path.join(img_folder, f"{i+1}.jpg"), cv2.IMREAD_GRAYSCALE)
    print("%08d.jpg" % i)
    print("%08d.jpg" % (i + 1))
    img_i = cv2.imread(os.path.join(img_folder, "%08d.jpg" % i), cv2.IMREAD_GRAYSCALE)
    img_j = cv2.imread(os.path.join(img_folder, "%08d.jpg" % (i + 1)), cv2.IMREAD_GRAYSCALE)
    img = img_j - img_i
    diff_id = np.where(img != 0)
    # for i in range(len(diff_id[0])):
    #     print(img[diff_id[0][i], diff_id[1][i]])
    # print(diff)
    plt.imshow(img)
    plt.show()
# Out:
# 00000001.jpg
# 00000002.jpg
# 00000002.jpg
# 00000003.jpg
# 00000003.jpg
# 00000004.jpg
# 00000004.jpg
# 00000005.jpg
# 00000005.jpg
# 00000006.jpg
# 00000006.jpg
# 00000007.jpg
# 00000007.jpg
# 00000008.jpg
# 00000008.jpg
# 00000009.jpg
# 00000009.jpg
# 00000010.jpg
# 00000010.jpg
# 00000011.jpg
# 00000011.jpg
# 00000012.jpg
# 00000012.jpg
# 00000013.jpg
# 00000013.jpg
# 00000014.jpg
# 00000014.jpg
# 00000015.jpg
# 00000015.jpg
# 00000016.jpg
# 00000016.jpg
# 00000017.jpg
# 00000017.jpg
# 00000018.jpg
# 00000018.jpg
# 00000019.jpg
# 00000019.jpg
# 00000020.jpg
# 00000020.jpg
# 00000021.jpg
# 00000021.jpg
# 00000022.jpg
# 00000022.jpg
# 00000023.jpg
# 00000023.jpg
# 00000024.jpg
# 00000024.jpg
# 00000025.jpg
# 00000025.jpg
# 00000026.jpg
# 00000026.jpg
# 00000027.jpg
# 00000027.jpg
# 00000028.jpg
# 00000028.jpg
# 00000029.jpg
# 00000029.jpg
# 00000030.jpg
